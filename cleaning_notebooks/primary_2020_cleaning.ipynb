# %%
import pandas as pd
import datetime
import mariadb
import numpy as np
from pathlib import Path

# %%
csv_path = Path().cwd().parent.joinpath('voter_history_files/2020.csv')
import_csv = pd.read_csv(csv_path, converters={'County Name': str, 'Voter Registration Number': str, 'Election Date':str, 'Election Type':str, 'Party': str, 'Ballot Style':str, 'Absentee':str, 'Provisional':str, 'Supplemental':str})
output_name = 'primary_2020.csv'

# %%
import_csv
# Out:
#         County Name Voter Registration Number Election Date     Election Type  \
# 0          COLQUITT                  07271776    01/28/2020  SPECIAL ELECTION
# 1          COLQUITT                  00006871    01/28/2020  SPECIAL ELECTION
# 2          COLQUITT                  00041320    01/28/2020  SPECIAL ELECTION
# 3          COLQUITT                  00267983    01/28/2020  SPECIAL ELECTION
# 4          COLQUITT                  00503206    01/28/2020  SPECIAL ELECTION
# ...             ...                       ...           ...               ...
# 8329265      DEKALB                  13476309    09/29/2020  SPECIAL ELECTION
# 8329266      FULTON                  04533303    09/29/2020  SPECIAL ELECTION
# 8329267      FULTON                  02399012    09/29/2020  SPECIAL ELECTION
# 8329268      DEKALB                  03963464    09/29/2020  SPECIAL ELECTION
# 8329269     CLAYTON                  06315554    09/29/2020  SPECIAL ELECTION
#
#         Party Ballot Style Absentee Provisional Supplemental
# 0                  REGULAR        N           N            N
# 1                  REGULAR        N           N            N
# 2                  REGULAR        N           N            N
# 3                  REGULAR        N           N            N
# 4                  REGULAR        N           N            N
# ...       ...          ...      ...         ...          ...
# 8329265            REGULAR        N           N            N
# 8329266            REGULAR        N           N            N
# 8329267          IN PERSON        Y           N            N
# 8329268            REGULAR        N           N            N
# 8329269          IN PERSON        Y           N            N
#
# [8329270 rows x 9 columns]

# %%
df = import_csv.copy()

# %%
df = df.rename(columns={'County Name': 'county_name', 'Voter Registration Number': 'voter_registration_number', 'Election Date': 'election_date', 'Election Type': 'election_type', 'Party': 'party', 'Ballot Style': 'ballot_style', 'Absentee': 'absentee', 'Provisional': 'provisional', 'Supplemental':'supplemental'})

# %%
def add_row_names(column):
    counter = 0
    row_name_list = []
    for row in column:
        counter += 1
        row_name_list.append(counter)
    return row_name_list

# %%
df.insert(0, 'row_names', add_row_names(df['county_name']))

# %%
def column_float_to_strings(column):
    string_list = []
    for entry in column:
        if str(entry) == 'nan':
            string_list.append("nan")
        else:
            string_list.append(str(entry))
    return string_list

# %%
def remove_last_two_digits(column):
    string_list = []
    for entry in column:
        string_list.append(entry[0:-2])
    return string_list

# %%
df['voter_registration_number'][df['voter_registration_number'].isnull()]
# Out:
# Series([], Name: voter_registration_number, dtype: object)

# %%
df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 0                1    COLQUITT                  07271776    01/28/2020
# 1                2    COLQUITT                  00006871    01/28/2020
# 2                3    COLQUITT                  00041320    01/28/2020
# 3                4    COLQUITT                  00267983    01/28/2020
# 4                5    COLQUITT                  00503206    01/28/2020
# ...            ...         ...                       ...           ...
# 8329265    8329266      DEKALB                  13476309    09/29/2020
# 8329266    8329267      FULTON                  04533303    09/29/2020
# 8329267    8329268      FULTON                  02399012    09/29/2020
# 8329268    8329269      DEKALB                  03963464    09/29/2020
# 8329269    8329270     CLAYTON                  06315554    09/29/2020
#
#             election_type party ballot_style absentee provisional supplemental
# 0        SPECIAL ELECTION            REGULAR        N           N            N
# 1        SPECIAL ELECTION            REGULAR        N           N            N
# 2        SPECIAL ELECTION            REGULAR        N           N            N
# 3        SPECIAL ELECTION            REGULAR        N           N            N
# 4        SPECIAL ELECTION            REGULAR        N           N            N
# ...                   ...   ...          ...      ...         ...          ...
# 8329265  SPECIAL ELECTION            REGULAR        N           N            N
# 8329266  SPECIAL ELECTION            REGULAR        N           N            N
# 8329267  SPECIAL ELECTION          IN PERSON        Y           N            N
# 8329268  SPECIAL ELECTION            REGULAR        N           N            N
# 8329269  SPECIAL ELECTION          IN PERSON        Y           N            N
#
# [8329270 rows x 10 columns]

# %%
def reformat_date(column):
    date_list = []
    for entry in column:
        date_list.append(f"{entry[6:10]}" + "-" + f"{entry[0:2]}" + "-" + f"{entry[3:5]}")
    return date_list

# %%
df['election_date'] = reformat_date(df['election_date'])

# %%
df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 0                1    COLQUITT                  07271776    2020-01-28
# 1                2    COLQUITT                  00006871    2020-01-28
# 2                3    COLQUITT                  00041320    2020-01-28
# 3                4    COLQUITT                  00267983    2020-01-28
# 4                5    COLQUITT                  00503206    2020-01-28
# ...            ...         ...                       ...           ...
# 8329265    8329266      DEKALB                  13476309    2020-09-29
# 8329266    8329267      FULTON                  04533303    2020-09-29
# 8329267    8329268      FULTON                  02399012    2020-09-29
# 8329268    8329269      DEKALB                  03963464    2020-09-29
# 8329269    8329270     CLAYTON                  06315554    2020-09-29
#
#             election_type party ballot_style absentee provisional supplemental
# 0        SPECIAL ELECTION            REGULAR        N           N            N
# 1        SPECIAL ELECTION            REGULAR        N           N            N
# 2        SPECIAL ELECTION            REGULAR        N           N            N
# 3        SPECIAL ELECTION            REGULAR        N           N            N
# 4        SPECIAL ELECTION            REGULAR        N           N            N
# ...                   ...   ...          ...      ...         ...          ...
# 8329265  SPECIAL ELECTION            REGULAR        N           N            N
# 8329266  SPECIAL ELECTION            REGULAR        N           N            N
# 8329267  SPECIAL ELECTION          IN PERSON        Y           N            N
# 8329268  SPECIAL ELECTION            REGULAR        N           N            N
# 8329269  SPECIAL ELECTION          IN PERSON        Y           N            N
#
# [8329270 rows x 10 columns]

# %%
df.value_counts('election_type')
# Out:
# election_type
# GENERAL                    4973992
# GENERAL PRIMARY            2281405
# GENERAL PRIMARY RUNOFF      662740
# PPP                         292293
# SPECIAL ELECTION             56974
# GENERAL ELECTION RUNOFF      33469
# SPECIAL ELECTION RUNOFF      28344
# RECALL                          53
# Name: count, dtype: int64

# %%
filtered_date_df = df[df['election_date'] == "2020-06-09"]

# %%
filtered_date_df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 5350104    5350105        COOK                  00578947    2020-06-09
# 5350105    5350106        COOK                  00611960    2020-06-09
# 5350106    5350107        COOK                  00610063    2020-06-09
# 5350107    5350108        COOK                  00962640    2020-06-09
# 5350108    5350109        COOK                  01220392    2020-06-09
# ...            ...         ...                       ...           ...
# 7631784    7631785      FULTON                  05323544    2020-06-09
# 7631785    7631786       UPSON                  04069157    2020-06-09
# 7631786    7631787       HENRY                  04034579    2020-06-09
# 7631787    7631788    GWINNETT                  10203088    2020-06-09
# 7631788    7631789    BRANTLEY                  05070231    2020-06-09
#
#             election_type       party ballot_style absentee provisional  \
# 5350104  SPECIAL ELECTION                  REGULAR        N           N
# 5350105  SPECIAL ELECTION                  REGULAR        N           N
# 5350106  SPECIAL ELECTION                  REGULAR        N           N
# 5350107  SPECIAL ELECTION                  REGULAR        N           N
# 5350108  SPECIAL ELECTION                  REGULAR        N           N
# ...                   ...         ...          ...      ...         ...
# 7631784   GENERAL PRIMARY    DEMOCRAT      REGULAR        N           N
# 7631785   GENERAL PRIMARY    DEMOCRAT      MAIL IN        Y           N
# 7631786   GENERAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7631787   GENERAL PRIMARY    DEMOCRAT      REGULAR        N           N
# 7631788   GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
#
#         supplemental
# 5350104            N
# 5350105            N
# 5350106            N
# 5350107            N
# 5350108            N
# ...              ...
# 7631784            N
# 7631785            N
# 7631786            N
# 7631787            N
# 7631788            N
#
# [2281685 rows x 10 columns]

# %%
filtered_date_df.value_counts('election_type')
# Out:
# election_type
# GENERAL PRIMARY     2281405
# SPECIAL ELECTION        280
# Name: count, dtype: int64

# %%
filtered_date_ppp = filtered_date_df[filtered_date_df['election_type'] == "GENERAL PRIMARY"]

# %%
filtered_date_ppp
# Out:
#          row_names county_name voter_registration_number election_date  \
# 5350384    5350385     APPLING                  00044647    2020-06-09
# 5350385    5350386     APPLING                  00047002    2020-06-09
# 5350386    5350387     APPLING                  00045730    2020-06-09
# 5350387    5350388     APPLING                  00122112    2020-06-09
# 5350388    5350389     APPLING                  00167836    2020-06-09
# ...            ...         ...                       ...           ...
# 7631784    7631785      FULTON                  05323544    2020-06-09
# 7631785    7631786       UPSON                  04069157    2020-06-09
# 7631786    7631787       HENRY                  04034579    2020-06-09
# 7631787    7631788    GWINNETT                  10203088    2020-06-09
# 7631788    7631789    BRANTLEY                  05070231    2020-06-09
#
#            election_type       party ballot_style absentee provisional  \
# 5350384  GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
# 5350385  GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
# 5350386  GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
# 5350387  GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
# 5350388  GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
# ...                  ...         ...          ...      ...         ...
# 7631784  GENERAL PRIMARY    DEMOCRAT      REGULAR        N           N
# 7631785  GENERAL PRIMARY    DEMOCRAT      MAIL IN        Y           N
# 7631786  GENERAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7631787  GENERAL PRIMARY    DEMOCRAT      REGULAR        N           N
# 7631788  GENERAL PRIMARY  REPUBLICAN      REGULAR        N           N
#
#         supplemental
# 5350384            N
# 5350385            N
# 5350386            N
# 5350387            N
# 5350388            N
# ...              ...
# 7631784            N
# 7631785            N
# 7631786            N
# 7631787            N
# 7631788            N
#
# [2281405 rows x 10 columns]

# %%
output_path = Path().cwd().parent.joinpath('output_csv/primary_2020.csv')
filtered_date_ppp.to_csv(output_path)
