# %%
import pandas as pd
import datetime
import mariadb
import numpy as np
from pathlib import Path

# %%
csv_path = Path().cwd().parent.joinpath('voter_history_files/A-12308.csv')
import_csv = pd.read_csv(csv_path, converters={'County Name': str, 'Voter Registration Number': str, 'Election Date':str, 'Election Type':str, 'Party': str, 'Ballot Style':str, 'Absentee':str, 'Provisional':str, 'Supplemental':str})
output_name = 'primary_2024.csv'

# %%
import_csv
# Out:
#        County Name Voter Registration Number Election Date    Election Type  \
# 0        JEFFERSON                  00240170    03/12/2024  GENERAL PRIMARY
# 1            EVANS                  03342675    03/12/2024  GENERAL PRIMARY
# 2           HARRIS                  02834398    03/12/2024  GENERAL PRIMARY
# 3         MCDUFFIE                  00214544    03/12/2024  GENERAL PRIMARY
# 4         STEPHENS                  01291547    03/12/2024  GENERAL PRIMARY
# ...            ...                       ...           ...              ...
# 886245     DOUGLAS                  11560651    03/12/2024  GENERAL PRIMARY
# 886246     DOUGLAS                  02967276    03/12/2024  GENERAL PRIMARY
# 886247      FULTON                  02642641    03/12/2024  GENERAL PRIMARY
# 886248       TROUP                  04825054    03/12/2024  GENERAL PRIMARY
# 886249     LIBERTY                  07105957    03/12/2024  GENERAL PRIMARY
#
#              Party        Ballot Style Absentee Provisional Supplemental
# 0         DEMOCRAT    ABSENTEE BY MAIL        Y                        N
# 1         DEMOCRAT    ABSENTEE BY MAIL        Y                        N
# 2       REPUBLICAN    ABSENTEE BY MAIL        Y                        N
# 3         DEMOCRAT    ABSENTEE BY MAIL        Y                        N
# 4         DEMOCRAT    ABSENTEE BY MAIL        Y                        N
# ...            ...                 ...      ...         ...          ...
# 886245    DEMOCRAT  ELECTION DAY (BMD)        Y           N            N
# 886246  REPUBLICAN  ELECTION DAY (BMD)        Y           N            N
# 886247  REPUBLICAN     EARLY IN-PERSON        Y                        N
# 886248  REPUBLICAN  ELECTION DAY (BMD)        Y           N            N
# 886249  REPUBLICAN  ELECTION DAY (BMD)        Y           N            N
#
# [886250 rows x 9 columns]

# %%
df = import_csv.copy()

# %%
df = df.rename(columns={'County Name': 'county_name', 'Voter Registration Number': 'voter_registration_number', 'Election Date': 'election_date', 'Election Type': 'election_type', 'Party': 'party', 'Ballot Style': 'ballot_style', 'Absentee': 'absentee', 'Provisional': 'provisional', 'Supplemental':'supplemental'})

# %%
def add_row_names(column):
    counter = 0
    row_name_list = []
    for row in column:
        counter += 1
        row_name_list.append(counter)
    return row_name_list

# %%
df.insert(0, 'row_names', add_row_names(df['county_name']))

# %%
def column_float_to_strings(column):
    string_list = []
    for entry in column:
        if str(entry) == 'nan':
            string_list.append("nan")
        else:
            string_list.append(str(entry))
    return string_list

# %%
def remove_last_two_digits(column):
    string_list = []
    for entry in column:
        string_list.append(entry[0:-2])
    return string_list

# %%
df['voter_registration_number'][df['voter_registration_number'].isnull()]
# Out:
# Series([], Name: voter_registration_number, dtype: object)

# %%
df
# Out:
#         row_names county_name voter_registration_number election_date  \
# 0               1   JEFFERSON                  00240170    03/12/2024
# 1               2       EVANS                  03342675    03/12/2024
# 2               3      HARRIS                  02834398    03/12/2024
# 3               4    MCDUFFIE                  00214544    03/12/2024
# 4               5    STEPHENS                  01291547    03/12/2024
# ...           ...         ...                       ...           ...
# 886245     886246     DOUGLAS                  11560651    03/12/2024
# 886246     886247     DOUGLAS                  02967276    03/12/2024
# 886247     886248      FULTON                  02642641    03/12/2024
# 886248     886249       TROUP                  04825054    03/12/2024
# 886249     886250     LIBERTY                  07105957    03/12/2024
#
#           election_type       party        ballot_style absentee provisional  \
# 0       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# 1       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# 2       GENERAL PRIMARY  REPUBLICAN    ABSENTEE BY MAIL        Y
# 3       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# 4       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# ...                 ...         ...                 ...      ...         ...
# 886245  GENERAL PRIMARY    DEMOCRAT  ELECTION DAY (BMD)        Y           N
# 886246  GENERAL PRIMARY  REPUBLICAN  ELECTION DAY (BMD)        Y           N
# 886247  GENERAL PRIMARY  REPUBLICAN     EARLY IN-PERSON        Y
# 886248  GENERAL PRIMARY  REPUBLICAN  ELECTION DAY (BMD)        Y           N
# 886249  GENERAL PRIMARY  REPUBLICAN  ELECTION DAY (BMD)        Y           N
#
#        supplemental
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ...             ...
# 886245            N
# 886246            N
# 886247            N
# 886248            N
# 886249            N
#
# [886250 rows x 10 columns]

# %%
def reformat_date(column):
    date_list = []
    for entry in column:
        date_list.append(f"{entry[6:10]}" + "-" + f"{entry[0:2]}" + "-" + f"{entry[3:5]}")
    return date_list

# %%
df['election_date'] = reformat_date(df['election_date'])

# %%
df
# Out:
#         row_names county_name voter_registration_number election_date  \
# 0               1   JEFFERSON                  00240170    2024-03-12
# 1               2       EVANS                  03342675    2024-03-12
# 2               3      HARRIS                  02834398    2024-03-12
# 3               4    MCDUFFIE                  00214544    2024-03-12
# 4               5    STEPHENS                  01291547    2024-03-12
# ...           ...         ...                       ...           ...
# 886245     886246     DOUGLAS                  11560651    2024-03-12
# 886246     886247     DOUGLAS                  02967276    2024-03-12
# 886247     886248      FULTON                  02642641    2024-03-12
# 886248     886249       TROUP                  04825054    2024-03-12
# 886249     886250     LIBERTY                  07105957    2024-03-12
#
#           election_type       party        ballot_style absentee provisional  \
# 0       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# 1       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# 2       GENERAL PRIMARY  REPUBLICAN    ABSENTEE BY MAIL        Y
# 3       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# 4       GENERAL PRIMARY    DEMOCRAT    ABSENTEE BY MAIL        Y
# ...                 ...         ...                 ...      ...         ...
# 886245  GENERAL PRIMARY    DEMOCRAT  ELECTION DAY (BMD)        Y           N
# 886246  GENERAL PRIMARY  REPUBLICAN  ELECTION DAY (BMD)        Y           N
# 886247  GENERAL PRIMARY  REPUBLICAN     EARLY IN-PERSON        Y
# 886248  GENERAL PRIMARY  REPUBLICAN  ELECTION DAY (BMD)        Y           N
# 886249  GENERAL PRIMARY  REPUBLICAN  ELECTION DAY (BMD)        Y           N
#
#        supplemental
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ...             ...
# 886245            N
# 886246            N
# 886247            N
# 886248            N
# 886249            N
#
# [886250 rows x 10 columns]

# %%
df.value_counts('election_type')
# Out:
# election_type
# GENERAL PRIMARY    886240
#                         5
# PPP                     3
# STATEWIDE               2
# Name: count, dtype: int64

# %%
output_path = Path().cwd().parent.joinpath('output_csv/primary_2024.csv')
df.to_csv(output_path)
