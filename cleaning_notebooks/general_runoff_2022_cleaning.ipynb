# %%
import pandas as pd
import datetime
import mariadb
import numpy as np
from pathlib import Path

# %%
csv_path = Path().cwd().parent.joinpath('voter_history_files/A-12147.csv')
import_csv = pd.read_csv(csv_path, converters={'County Name': str, 'Voter Registration Number': str, 'Election Date':str, 'Election Type':str, 'Party': str, 'Ballot Style':str, 'Absentee':str, 'Provisional':str, 'Supplemental':str})

# %%
import_csv
# Out:
#         County Name Voter Registration Number Election Date  \
# 0           APPLING                  00648862    12/06/2022
# 1           APPLING                  00651735    12/06/2022
# 2           APPLING                  03679018    12/06/2022
# 3              DADE                  05612337    12/06/2022
# 4          GWINNETT                  06954777    12/06/2022
# ...             ...                       ...           ...
# 3538425      FULTON                  13530227    12/06/2022
# 3538426      FULTON                  13167645    12/06/2022
# 3538427      FULTON                  13502513    12/06/2022
# 3538428     DOUGLAS                  04971785    12/06/2022
# 3538429   EFFINGHAM                  12555574    12/06/2022
#
#                    Election Type Party      Ballot Style Absentee Provisional  \
# 0        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 1        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 2        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 3        GENERAL ELECTION RUNOFF                 REGULAR        N           Y
# 4        GENERAL ELECTION RUNOFF                   EARLY        N           N
# ...                          ...   ...               ...      ...         ...
# 3538425  GENERAL ELECTION RUNOFF        ABSENTEE BY MAIL        Y
# 3538426  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538427  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538428  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538429  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
#
#         Supplemental
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 3538425            N
# 3538426            N
# 3538427            N
# 3538428            N
# 3538429            N
#
# [3538430 rows x 9 columns]

# %%
df = import_csv.copy()

# %%
df = df.rename(columns={'County Name': 'county_name', 'Voter Registration Number': 'voter_registration_number', 'Election Date': 'election_date', 'Election Type': 'election_type', 'Party': 'party', 'Ballot Style': 'ballot_style', 'Absentee': 'absentee', 'Provisional': 'provisional', 'Supplemental':'supplemental'})

# %%
def add_row_names(column):
    counter = 0
    row_name_list = []
    for row in column:
        counter += 1
        row_name_list.append(counter)
    return row_name_list

# %%
df.insert(0, 'row_names', add_row_names(df['county_name']))

# %%
def column_float_to_strings(column):
    string_list = []
    for entry in column:
        if str(entry) == 'nan':
            string_list.append("nan")
        else:
            string_list.append(str(entry))
    return string_list

# %%
def remove_last_two_digits(column):
    string_list = []
    for entry in column:
        string_list.append(entry[0:-2])
    return string_list

# %%
df['voter_registration_number'][df['voter_registration_number'].isnull()]
# Out:
# Series([], Name: voter_registration_number, dtype: object)

# %%
df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 0                1     APPLING                  00648862    12/06/2022
# 1                2     APPLING                  00651735    12/06/2022
# 2                3     APPLING                  03679018    12/06/2022
# 3                4        DADE                  05612337    12/06/2022
# 4                5    GWINNETT                  06954777    12/06/2022
# ...            ...         ...                       ...           ...
# 3538425    3538426      FULTON                  13530227    12/06/2022
# 3538426    3538427      FULTON                  13167645    12/06/2022
# 3538427    3538428      FULTON                  13502513    12/06/2022
# 3538428    3538429     DOUGLAS                  04971785    12/06/2022
# 3538429    3538430   EFFINGHAM                  12555574    12/06/2022
#
#                    election_type party      ballot_style absentee provisional  \
# 0        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 1        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 2        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 3        GENERAL ELECTION RUNOFF                 REGULAR        N           Y
# 4        GENERAL ELECTION RUNOFF                   EARLY        N           N
# ...                          ...   ...               ...      ...         ...
# 3538425  GENERAL ELECTION RUNOFF        ABSENTEE BY MAIL        Y
# 3538426  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538427  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538428  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538429  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
#
#         supplemental
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 3538425            N
# 3538426            N
# 3538427            N
# 3538428            N
# 3538429            N
#
# [3538430 rows x 10 columns]

# %%
def reformat_date(column):
    date_list = []
    for entry in column:
        date_list.append(f"{entry[6:10]}" + "-" + f"{entry[0:2]}" + "-" + f"{entry[3:5]}")
    return date_list

# %%
df['election_date'] = reformat_date(df['election_date'])

# %%
df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 0                1     APPLING                  00648862    2022-12-06
# 1                2     APPLING                  00651735    2022-12-06
# 2                3     APPLING                  03679018    2022-12-06
# 3                4        DADE                  05612337    2022-12-06
# 4                5    GWINNETT                  06954777    2022-12-06
# ...            ...         ...                       ...           ...
# 3538425    3538426      FULTON                  13530227    2022-12-06
# 3538426    3538427      FULTON                  13167645    2022-12-06
# 3538427    3538428      FULTON                  13502513    2022-12-06
# 3538428    3538429     DOUGLAS                  04971785    2022-12-06
# 3538429    3538430   EFFINGHAM                  12555574    2022-12-06
#
#                    election_type party      ballot_style absentee provisional  \
# 0        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 1        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 2        GENERAL ELECTION RUNOFF                ABSENTEE        N           N
# 3        GENERAL ELECTION RUNOFF                 REGULAR        N           Y
# 4        GENERAL ELECTION RUNOFF                   EARLY        N           N
# ...                          ...   ...               ...      ...         ...
# 3538425  GENERAL ELECTION RUNOFF        ABSENTEE BY MAIL        Y
# 3538426  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538427  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538428  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
# 3538429  GENERAL ELECTION RUNOFF         EARLY IN-PERSON        Y
#
#         supplemental
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 3538425            N
# 3538426            N
# 3538427            N
# 3538428            N
# 3538429            N
#
# [3538430 rows x 10 columns]

# %%
df[df['election_type'] != "GENERAL ELECTION RUNOFF"]
# Out:
#          row_names county_name voter_registration_number election_date  \
# 1631361    1631362    GWINNETT                  01973288    2022-12-06
# 1631362    1631363    SPALDING                  08804677    2022-12-06
# 1631370    1631371   DOUGHERTY                  05916828    2022-12-06
# 1631372    1631373    RICHMOND                  07731788    2022-12-06
# 1631378    1631379      MORGAN                  06210249    2022-12-06
# ...            ...         ...                       ...           ...
# 2589961    2589962      NEWTON                  01980010    2022-12-06
# 2589962    2589963      MURRAY                  02236419    2022-12-06
# 2589963    2589964      FULTON                  02365647    2022-12-06
# 2633754    2633755      FULTON                  02636318    2022-12-06
# 2873637    2873638  MONTGOMERY                  11787356    2022-12-06
#
#         election_type party      ballot_style absentee provisional  \
# 1631361       GENERAL        ABSENTEE BY MAIL        Y
# 1631362       GENERAL        ABSENTEE BY MAIL        Y
# 1631370       GENERAL        ABSENTEE BY MAIL        Y
# 1631372       GENERAL        ABSENTEE BY MAIL        Y
# 1631378       GENERAL        ABSENTEE BY MAIL        Y
# ...               ...   ...               ...      ...         ...
# 2589961       GENERAL         EARLY IN-PERSON        Y
# 2589962       GENERAL         EARLY IN-PERSON        Y
# 2589963       GENERAL         EARLY IN-PERSON        Y
# 2633754       GENERAL         EARLY IN-PERSON        Y
# 2873637       GENERAL         EARLY IN-PERSON        Y
#
#         supplemental
# 1631361            N
# 1631362            N
# 1631370            N
# 1631372            N
# 1631378            N
# ...              ...
# 2589961            N
# 2589962            N
# 2589963            N
# 2633754            N
# 2873637            N
#
# [828923 rows x 10 columns]

# %%
df.value_counts('election_type')
# Out:
# election_type
# GENERAL ELECTION RUNOFF    2709507
# GENERAL                     828923
# Name: count, dtype: int64

# %%
output_path = Path().cwd().parent.joinpath('output_csv/general_runoff_2022.csv')
df.to_csv(output_path)
