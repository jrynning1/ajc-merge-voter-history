# %%
import pandas as pd
import datetime
import mariadb
import numpy as np
from pathlib import Path

# %%
csv_path = Path().cwd().parent.joinpath('voter_history_files/2018.csv')
import_csv = pd.read_csv(csv_path, converters={'County Name': str, 'Voter Registration Number': str, 'Election Date':str, 'Election Type':str, 'Party': str, 'Ballot Style':str, 'Absentee':str, 'Provisional':str, 'Supplemental':str})

# %%
import_csv
# Out:
#         County Name Voter Registration Number Election Date     Election Type  \
# 0          MCDUFFIE                  00200975    01/30/2018  SPECIAL ELECTION
# 1          MCDUFFIE                  00214376    01/30/2018  SPECIAL ELECTION
# 2          MCDUFFIE                  00214519    01/30/2018  SPECIAL ELECTION
# 3          MCDUFFIE                  00222361    01/30/2018  SPECIAL ELECTION
# 4          MCDUFFIE                  00222385    01/30/2018  SPECIAL ELECTION
# ...             ...                       ...           ...               ...
# 7462150      LANIER                  00710452    08/21/2018   SPECIAL PRIMARY
# 7462151      LANIER                  00710201    08/21/2018   SPECIAL PRIMARY
# 7462152      LANIER                  00710092    08/21/2018   SPECIAL PRIMARY
# 7462153      LANIER                  00710585    08/21/2018   SPECIAL PRIMARY
# 7462154      LANIER                  00708651    08/21/2018   SPECIAL PRIMARY
#
#               Party Ballot Style Absentee Provisional Supplemental
# 0                        REGULAR        N           N            N
# 1                        REGULAR        N           N            N
# 2                        REGULAR        N           N            N
# 3                        REGULAR        N           N            N
# 4                        REGULAR        N           N            N
# ...             ...          ...      ...         ...          ...
# 7462150  REPUBLICAN    IN PERSON        Y           N            N
# 7462151  REPUBLICAN      MAIL IN        Y           N            N
# 7462152  REPUBLICAN    IN PERSON        Y           N            N
# 7462153  REPUBLICAN    IN PERSON        Y           N            N
# 7462154  REPUBLICAN        EARLY        N           N            Y
#
# [7462155 rows x 9 columns]

# %%
df = import_csv.copy()

# %%
df = df.rename(columns={'County Name': 'county_name', 'Voter Registration Number': 'voter_registration_number', 'Election Date': 'election_date', 'Election Type': 'election_type', 'Party': 'party', 'Ballot Style': 'ballot_style', 'Absentee': 'absentee', 'Provisional': 'provisional', 'Supplemental':'supplemental'})

# %%
def add_row_names(column):
    counter = 0
    row_name_list = []
    for row in column:
        counter += 1
        row_name_list.append(counter)
    return row_name_list

# %%
df.insert(0, 'row_names', add_row_names(df['county_name']))

# %%
def column_float_to_strings(column):
    string_list = []
    for entry in column:
        if str(entry) == 'nan':
            string_list.append("nan")
        else:
            string_list.append(str(entry))
    return string_list

# %%
def remove_last_two_digits(column):
    string_list = []
    for entry in column:
        string_list.append(entry[0:-2])
    return string_list

# %%
df['voter_registration_number'][df['voter_registration_number'].isnull()]
# Out:
# Series([], Name: voter_registration_number, dtype: object)

# %%
df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 0                1    MCDUFFIE                  00200975    01/30/2018
# 1                2    MCDUFFIE                  00214376    01/30/2018
# 2                3    MCDUFFIE                  00214519    01/30/2018
# 3                4    MCDUFFIE                  00222361    01/30/2018
# 4                5    MCDUFFIE                  00222385    01/30/2018
# ...            ...         ...                       ...           ...
# 7462150    7462151      LANIER                  00710452    08/21/2018
# 7462151    7462152      LANIER                  00710201    08/21/2018
# 7462152    7462153      LANIER                  00710092    08/21/2018
# 7462153    7462154      LANIER                  00710585    08/21/2018
# 7462154    7462155      LANIER                  00708651    08/21/2018
#
#             election_type       party ballot_style absentee provisional  \
# 0        SPECIAL ELECTION                  REGULAR        N           N
# 1        SPECIAL ELECTION                  REGULAR        N           N
# 2        SPECIAL ELECTION                  REGULAR        N           N
# 3        SPECIAL ELECTION                  REGULAR        N           N
# 4        SPECIAL ELECTION                  REGULAR        N           N
# ...                   ...         ...          ...      ...         ...
# 7462150   SPECIAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7462151   SPECIAL PRIMARY  REPUBLICAN      MAIL IN        Y           N
# 7462152   SPECIAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7462153   SPECIAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7462154   SPECIAL PRIMARY  REPUBLICAN        EARLY        N           N
#
#         supplemental
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 7462150            N
# 7462151            N
# 7462152            N
# 7462153            N
# 7462154            Y
#
# [7462155 rows x 10 columns]

# %%
def reformat_date(column):
    date_list = []
    for entry in column:
        date_list.append(f"{entry[6:10]}" + "-" + f"{entry[0:2]}" + "-" + f"{entry[3:5]}")
    return date_list

# %%
df['election_date'] = reformat_date(df['election_date'])

# %%
df
# Out:
#          row_names county_name voter_registration_number election_date  \
# 0                1    MCDUFFIE                  00200975    2018-01-30
# 1                2    MCDUFFIE                  00214376    2018-01-30
# 2                3    MCDUFFIE                  00214519    2018-01-30
# 3                4    MCDUFFIE                  00222361    2018-01-30
# 4                5    MCDUFFIE                  00222385    2018-01-30
# ...            ...         ...                       ...           ...
# 7462150    7462151      LANIER                  00710452    2018-08-21
# 7462151    7462152      LANIER                  00710201    2018-08-21
# 7462152    7462153      LANIER                  00710092    2018-08-21
# 7462153    7462154      LANIER                  00710585    2018-08-21
# 7462154    7462155      LANIER                  00708651    2018-08-21
#
#             election_type       party ballot_style absentee provisional  \
# 0        SPECIAL ELECTION                  REGULAR        N           N
# 1        SPECIAL ELECTION                  REGULAR        N           N
# 2        SPECIAL ELECTION                  REGULAR        N           N
# 3        SPECIAL ELECTION                  REGULAR        N           N
# 4        SPECIAL ELECTION                  REGULAR        N           N
# ...                   ...         ...          ...      ...         ...
# 7462150   SPECIAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7462151   SPECIAL PRIMARY  REPUBLICAN      MAIL IN        Y           N
# 7462152   SPECIAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7462153   SPECIAL PRIMARY  REPUBLICAN    IN PERSON        Y           N
# 7462154   SPECIAL PRIMARY  REPUBLICAN        EARLY        N           N
#
#         supplemental
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ...              ...
# 7462150            N
# 7462151            N
# 7462152            N
# 7462153            N
# 7462154            Y
#
# [7462155 rows x 10 columns]

# %%
df = df[df['election_type'] == "GENERAL"]

# %%
output_path = Path().cwd().parent.joinpath('output_csv/general_2018.csv')
df.to_csv(output_path)

# %%
df.value_counts('election_type')
# Out:
# election_type
# GENERAL    3942933
# Name: count, dtype: int64
